# %%
import pandas
import os
#VAMOS A EXTRAER DATOS DE UNA PAGINA WEB https://pokemondb.net/pokedex/all  UTILIZANDO  import requests
import requests

# %%
#EXTRAEMOS EL CODIGO
url = "https://pokemondb.net/pokedex/all"
html_text = requests.get(url).content

# %%
 #CREAMOS UN DATAFREAM
contenido = pandas.read_html(html_text)

# %%
# extraemos los datos
df_pokedex = contenido[0]

# %%
df_pokedex
# Out:
#         #                    Name           Type  ...  Sp. Atk  Sp. Def  Speed
# 0       1               Bulbasaur   Grass Poison  ...       65       65     45
# 1       2                 Ivysaur   Grass Poison  ...       80       80     60
# 2       3                Venusaur   Grass Poison  ...      100      100     80
# 3       3  Venusaur Mega Venusaur   Grass Poison  ...      122      120     80
# 4       4              Charmander           Fire  ...       60       50     65
# ...   ...                     ...            ...  ...      ...      ...    ...
# 1040  896               Glastrier            Ice  ...       65      110     30
# 1041  897               Spectrier          Ghost  ...      145       80    130
# 1042  898                 Calyrex  Psychic Grass  ...       80       80     80
# 1043  898       Calyrex Ice Rider    Psychic Ice  ...       85      130     50
# 1044  898    Calyrex Shadow Rider  Psychic Ghost  ...      165      100    150
#
# ...

# %%
#CON EL COMANDO .head() podemos mirar solamente el encabezado de una lista ejemplo. si queremos ampliar el parametro se coloca el numero
df_pokedex.head(10)
# Out:
#    #                        Name          Type  ...  Sp. Atk  Sp. Def  Speed
# 0  1                   Bulbasaur  Grass Poison  ...       65       65     45
# 1  2                     Ivysaur  Grass Poison  ...       80       80     60
# 2  3                    Venusaur  Grass Poison  ...      100      100     80
# 3  3      Venusaur Mega Venusaur  Grass Poison  ...      122      120     80
# 4  4                  Charmander          Fire  ...       60       50     65
# 5  5                  Charmeleon          Fire  ...       80       65     80
# 6  6                   Charizard   Fire Flying  ...      109       85    100
# 7  6  Charizard Mega Charizard X   Fire Dragon  ...      130       85    100
# 8  6  Charizard Mega Charizard Y   Fire Flying  ...      159      115    100
# 9  7                    Squirtle         Water  ...       50       64     43
#
# [10 rows x 10 columns]

# %%
#SI QUEREMOS SABER CUANTOS REGISTROS HAY EN LA TABLA UTILIZAMOS EL METODO shape
df_pokedex.shape
# Out:
# (1045, 10)

# %%
 #PARA SABER LA INFORMACION DE NUESTRA TABLA
 df_pokedex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1045 entries, 0 to 1044
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   #        1045 non-null   int64
#  1   Name     1045 non-null   object
#  2   Type     1045 non-null   object
#  3   Total    1045 non-null   int64
#  4   HP       1045 non-null   int64
#  5   Attack   1045 non-null   int64
#  6   Defense  1045 non-null   int64
#  7   Sp. Atk  1045 non-null   int64
#  8   Sp. Def  1045 non-null   int64
#  9   Speed    1045 non-null   int64
# dtypes: int64(8), object(2)
# memory usage: 81.8+ KB

# %%
#NOS PERMITE TERNER UNAS ESTADISTICAS DESCRIPTIVAS 
df_pokedex.describe()
# Out:
#                  #        Total  ...      Sp. Def        Speed
# count  1045.000000  1045.000000  ...  1045.000000  1045.000000
# mean    440.769378   439.314833  ...    72.288995    68.807656
# std     262.517231   121.970701  ...    28.074148    30.210094
# min       1.000000   175.000000  ...    20.000000     5.000000
# 25%     212.000000   330.000000  ...    50.000000    45.000000
# 50%     436.000000   458.000000  ...    70.000000    65.000000
# 75%     670.000000   515.000000  ...    90.000000    90.000000
# max     898.000000  1125.000000  ...   250.000000   200.000000
#
# [8 rows x 8 columns]
